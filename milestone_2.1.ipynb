# %%
# -------------------------
# 1. Install Java and Spark + findspark
# -------------------------
# !apt-get install openjdk-8-jdk -y
# !pip install -q findspark azure-eventhub

import os
import subprocess
import shutil
import json
import time
import pandas as pd
from azure.eventhub import EventHubProducerClient, EventData
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, TimestampType
from pyspark.sql.functions import from_json, expr
from pyspark.sql import SparkSession

# Descargar Spark
spark_version = subprocess.run(
    "curl -s https://downloads.apache.org/spark/ | grep -o 'spark-3\\.[0-9]\\+\\.[0-9]\\+' | sort -V | tail -1",
    shell=True, capture_output=True, text=True
).stdout.strip()

spark_release = spark_version
hadoop_version = "hadoop3"
tgz_file = f"{spark_release}-bin-{hadoop_version}.tgz"
spark_dir = f"{spark_release}-bin-{hadoop_version}"
spark_url = f"https://downloads.apache.org/spark/{spark_release}/{tgz_file}"

if not os.path.exists(tgz_file):
    # !wget -q {spark_url}
if os.path.exists(spark_dir):
    shutil.rmtree(spark_dir)
# !tar xf {tgz_file}

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_dir}"

import findspark
findspark.init()

# -------------------------
# 2. Create SparkSession
# -------------------------
spark = SparkSession.builder \
    .appName("UberStreamingPipeline") \
    .config("spark.jars.packages", ",".join([
        "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1",
        "org.apache.spark:spark-avro_2.12:3.4.1",
        "org.apache.hadoop:hadoop-azure:3.3.1",
        "com.microsoft.azure:azure-storage:8.6.6"
    ])) \
    .config("spark.sql.extensions", "org.apache.spark.sql.avro.AvroSqlExtensions") \
    .getOrCreate()

# -------------------------
# 3. Configure Azure Event Hub
# -------------------------
namespace = "iesstsabbadbab-grp-01-05"
conn_str = "Endpoint=sb://iesstsabbadbab-grp-01-05.servicebus.windows.net/;SharedAccessKeyName=RootManageSharedAccessKey;SharedAccessKey=KFsFTha8Ojs7lrblvgJoOEkE/wL16nf0/+AEhHOIKkI="
ride_topic = "ride-events-group4"
traffic_topic = "traffic-alerts-group4"

common_kafka_options = {
    "kafka.bootstrap.servers": f"{namespace}.servicebus.windows.net:9093",
    "kafka.sasl.mechanism": "PLAIN",
    "kafka.security.protocol": "SASL_SSL",
    "kafka.sasl.jaas.config": f'org.apache.kafka.common.security.plain.PlainLoginModule required username="$ConnectionString" password="{conn_str}";',
    "startingOffsets": "earliest"
}

# -------------------------
# 4. Load events from JSON files
# -------------------------
ride_path = "/content/ride_events.json"
traffic_path = "/content/traffic_surge_alerts.json"

with open(ride_path, "r") as f:
    ride_events = json.load(f)
with open(traffic_path, "r") as f:
    traffic_alerts_raw = json.load(f)

traffic_alerts = []
for zone, alerts in traffic_alerts_raw.items():
    for alert in alerts:
        traffic_alerts.append(alert)

# -------------------------
# 5. Define schemas and read from Kafka
# -------------------------
ride_schema = StructType([
    StructField("event_id", StringType()),
    StructField("ride_id", StringType()),
    StructField("event_type", StringType()),
    StructField("uber_type", StringType()),
    StructField("start_location", StringType()),
    StructField("end_location", StringType()),
    StructField("timestamp_event", StringType()),
    StructField("price", DoubleType())
])

traffic_schema = StructType([
    StructField("alert_id", StringType()),
    StructField("timestamp", StringType()),
    StructField("zone_id", StringType()),
    StructField("traffic_level", StringType()),
    StructField("event_type", StringType()),
    StructField("surge_multiplier", DoubleType())
])

ride_df = spark.readStream \
    .format("kafka") \
    .option("subscribe", ride_topic) \
    .options(**common_kafka_options) \
    .load() \
    .selectExpr("CAST(value AS STRING) as json_str") \
    .select(from_json("json_str", ride_schema).alias("data")) \
    .select("data.*") \
    .withColumn("timestamp_event", expr("to_timestamp(timestamp_event)"))

traffic_df = spark.readStream \
    .format("kafka") \
    .option("subscribe", traffic_topic) \
    .options(**common_kafka_options) \
    .load() \
    .selectExpr("CAST(value AS STRING) as json_str") \
    .select(from_json("json_str", traffic_schema).alias("data")) \
    .select("data.*") \
    .withColumn("timestamp", expr("to_timestamp(timestamp)"))

# -------------------------
# 6. Iniciate streams in memory
# -------------------------
for s in spark.streams.active:
    s.stop()

ride_preview_query = ride_df.writeStream \
    .format("memory") \
    .queryName("ride_events_table") \
    .outputMode("append") \
    .start()

traffic_preview_query = traffic_df.writeStream \
    .format("memory") \
    .queryName("traffic_alerts_table") \
    .outputMode("append") \
    .start()

# -------------------------
# 7. Send events to the Event Hub
# -------------------------
def send_events():
    send_events_to_eventhub(ride_events, ride_topic)
    send_events_to_eventhub(traffic_alerts, traffic_topic)

for _ in range(5):  # send 5 batches
    send_events()
    time.sleep(10)

# -------------------------
# 8. Wait and show the tables
# -------------------------
time.sleep(30)

print("\n\U0001F697 Preview: Ride Events desde AVRO deserializado")
spark.sql("SELECT * FROM ride_events_table").show(truncate=False)

print("\n\U0001F6A6 Preview: Traffic Alerts desde AVRO deserializado")
spark.sql("SELECT * FROM traffic_alerts_table").show(truncate=False)

# -------------------------
# 9. Store in Azure Blob Storage
# -------------------------
spark.conf.set(f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net", storage_account_key)
wasbs_base_path = f"wasbs://{container_name}@{storage_account_name}.blob.core.windows.net/"

ride_query = ride_df.writeStream \
    .format("parquet") \
    .option("path", wasbs_base_path + "ride_stream") \
    .option("checkpointLocation", "/content/checkpoints/ride_stream") \
    .outputMode("append") \
    .start()

traffic_query = traffic_df.writeStream \
    .format("parquet") \
    .option("path", wasbs_base_path + "traffic_stream") \
    .option("checkpointLocation", "/content/checkpoints/traffic_stream") \
    .outputMode("append") \
    .start()

# -------------------------
# 10. Monitor Streams - Debugging Output
# -------------------------
import time

try:
    print("\nMonitoring stream progress for 1 minute...\n")
    for _ in range(6):  # every 10 seconds, total 1 minute
        print(">>>RIDE STREAM STATUS:")
        print(ride_query.status)
        print("Progress:", ride_query.recentProgress)

        print("\n>>>TRAFFIC STREAM STATUS:")
        print(traffic_query.status)
        print("Progress:", traffic_query.recentProgress)

        time.sleep(10)

    print("\nMonitor finished: End of debug cycle.")

except Exception as e:
    print(f"\nError in monitoring: {e}")
finally:
    ride_query.stop()
    traffic_query.stop()
    print("\nStreams interrupted correctly.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openjdk-8-jdk is already the newest version (8u442-b06~us1-0ubuntu1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# 400 events sent to 'ride-events-group4'
# 100 events sent to 'traffic-alerts-group4'
# 400 events sent to 'ride-events-group4'
# 100 events sent to 'traffic-alerts-group4'
# 400 events sent to 'ride-events-group4'
# 100 events sent to 'traffic-alerts-group4'
# 400 events sent to 'ride-events-group4'
# 100 events sent to 'traffic-alerts-group4'
# 400 events sent to 'ride-events-group4'
# 100 events sent to 'traffic-alerts-group4'
#
# Preview: Ride Events from AVRO deserialized
# +------------------------------------+------------------------------------+----------------+------------+---------------------------+-------------------+--------------------------+-----+
# |event_id                            |ride_id                             |event_type      |uber_type   |start_location             |end_location       |timestamp_event           |price|
# +------------------------------------+------------------------------------+----------------+------------+---------------------------+-------------------+--------------------------+-----+
# |6f1a1234-6785-4505-81c9-8da56039b574|f08afdcf-ed3c-45be-a5ca-29b563f3384e|Request         |regular_uber|Plaza Mayor, Madrid        |Gran Via, Madrid   |2025-03-14 16:20:01.850881|NULL |
# |4b2d5dc8-3d98-4413-abaa-180d26077319|f08afdcf-ed3c-45be-a5ca-29b563f3384e|Driver available|regular_uber|Plaza Mayor, Madrid        |Gran Via, Madrid   |2025-03-14 16:20:06.850881|NULL |
# |8b779c1c-167f-4d65-ae1b-c73fa01e5ccd|f08afdcf-ed3c-45be-a5ca-29b563f3384e|Start car ride  |regular_uber|Plaza Mayor, Madrid        |Gran Via, Madrid   |2025-03-14 16:20:16.850881|3.94 |
# |058fd86a-16e9-48df-a6ae-8f1e70cb8eac|f08afdcf-ed3c-45be-a5ca-29b563f3384e|Ride finished   |regular_uber|Plaza Mayor, Madrid        |Gran Via, Madrid   |2025-03-14 16:20:41.850881|3.94 |
# |a96253e5-ff8c-4fa7-bef3-5c26803d51ca|f26a42af-12ac-4efa-a18d-a6426b246d54|Request         |regular_uber|Barrio de Salamanca, Madrid|Plaza Mayor, Madrid|2025-03-14 16:20:52.850881|NULL |
# |e573172a-4657-428f-bd77-434c12978c58|f26a42af-12ac-4efa-a18d-a6426b246d54|Driver available|regular_uber|Barrio de Salamanca, Madrid|Plaza Mayor, Madrid|2025-03-14 16:20:57.850881|NULL |
# |5e822c49-6764-43e7-997a-0aa28479743a|f26a42af-12ac-4efa-a18d-a6426b246d54|Start car ride  |regular_uber|Barrio de Salamanca, Madrid|Plaza Mayor, Madrid|2025-03-14 16:21:07.850881|4.19 |
# |be3e085d-dd54-4afd-b22b-ff973d6e624f|f26a42af-12ac-4efa-a18d-a6426b246d54|Ride finished   |regular_uber|Barrio de Salamanca, Madrid|Plaza Mayor, Madrid|2025-03-14 16:21:30.350881|4.19 |
# |b4564b50-0f32-45a8-8c7c-447ccb1e8ffc|e8999989-9877-45e9-a048-22554e417e78|Request         |uber_share  |Atocha, Madrid             |Chueca, Madrid     |2025-03-14 16:21:34.350881|NULL |
# |a9d1350b-7bb4-4fa4-9e19-ed1e8ffcc065|e8999989-9877-45e9-a048-22554e417e78|Driver available|uber_share  |Atocha, Madrid             |Chueca, Madrid     |2025-03-14 16:21:39.350881|NULL |
# |4c1eca81-fbef-4b32-831d-97e5e59a755f|e8999989-9877-45e9-a048-22554e417e78|Start car ride  |uber_share  |Atocha, Madrid             |Chueca, Madrid     |2025-03-14 16:21:49.350881|3.87 |
# |05c3ee8e-8714-4180-b5dd-491050aea1a8|e8999989-9877-45e9-a048-22554e417e78|Ride finished   |uber_share  |Atocha, Madrid             |Chueca, Madrid     |2025-03-14 16:22:14.350881|3.87 |
# |5b2afac8-5cfe-4418-9eb9-509899acc72c|d8d43549-ed99-440e-aaec-b08ea8a9ac44|Request         |uber_share  |Plaza Mayor, Madrid        |Moncloa, Madrid    |2025-03-14 16:22:31.350881|NULL |
# |17853a06-529e-4d08-b49a-31c6cc389b67|d8d43549-ed99-440e-aaec-b08ea8a9ac44|Driver available|uber_share  |Plaza Mayor, Madrid        |Moncloa, Madrid    |2025-03-14 16:22:36.350881|NULL |
# |1cc6129a-18d2-4fbf-aefe-0dbeae791082|d8d43549-ed99-440e-aaec-b08ea8a9ac44|Start car ride  |uber_share  |Plaza Mayor, Madrid        |Moncloa, Madrid    |2025-03-14 16:22:46.350881|3.92 |
# |28840431-2ae0-4d41-abea-60700c04a99e|d8d43549-ed99-440e-aaec-b08ea8a9ac44|Ride finished   |uber_share  |Plaza Mayor, Madrid        |Moncloa, Madrid    |2025-03-14 16:23:11.350881|3.92 |
# |4c8e0b3f-0b57-41e4-8e16-4fb16cffcf2f|e34c82ce-3e80-4b42-97e6-3631dc3d8834|Request         |regular_uber|Puerta del Sol, Madrid     |Atocha, Madrid     |2025-03-14 16:23:12.350881|NULL |
# |d8692fe4-0114-4538-abcb-0caf0fa88dcb|e34c82ce-3e80-4b42-97e6-3631dc3d8834|Driver available|regular_uber|Puerta del Sol, Madrid     |Atocha, Madrid     |2025-03-14 16:23:17.350881|NULL |
# |9a23be9f-7931-4d11-a1ef-e59c28645057|e34c82ce-3e80-4b42-97e6-3631dc3d8834|Start car ride  |regular_uber|Puerta del Sol, Madrid     |Atocha, Madrid     |2025-03-14 16:23:27.350881|4.05 |
# |c5dd1726-00a7-4e35-9ec2-ed39c29afcf7|e34c82ce-3e80-4b42-97e6-3631dc3d8834|Ride finished   |regular_uber|Puerta del Sol, Madrid     |Atocha, Madrid     |2025-03-14 16:23:48.350881|4.05 |
# +------------------------------------+------------------------------------+----------------+------------+---------------------------+-------------------+--------------------------+-----+
# only showing top 20 rows
#
#
# Preview: Traffic Alerts desde AVRO deserializado
# +------------------------------------+--------------------------+----------------+-------------+---------------+----------------+
# |alert_id                            |timestamp                 |zone_id         |traffic_level|event_type     |surge_multiplier|
# +------------------------------------+--------------------------+----------------+-------------+---------------+----------------+
# |fb64b065-f0a7-4e8c-a5d2-75bb48203fb7|2025-02-20 00:39:02.418685|Malasaña, Madrid|moderate     |roadwork       |1.2             |
# |56ec0c76-fe23-4041-a309-df47e255d49a|2025-02-03 11:02:22.148008|Malasaña, Madrid|moderate     |road congestion|1.2             |
# |86c9b201-8745-43ec-909d-7c1a3dee79ef|2025-01-21 06:20:44.676905|Malasaña, Madrid|severe       |road congestion|2.0             |
# |c851ca6c-8779-4d04-958c-3b1f543ff83a|2025-03-05 01:02:45.955626|Malasaña, Madrid|severe       |road congestion|2.0             |
# |da7e278f-1470-407c-8bce-aa642828c5a2|2025-01-04 06:43:40.157349|Malasaña, Madrid|moderate     |road congestion|1.2             |
# |dc4ebd4b-4aa8-45d9-a333-d2000f1ef660|2025-01-13 02:08:45.001225|Malasaña, Madrid|low          |roadwork       |1.0             |
# |80b5e100-755c-4fc1-bea0-c28874de6943|2025-02-01 03:27:45.576348|Malasaña, Madrid|severe       |accident       |2.0             |
# |c7d719df-a879-4a43-804a-e8c227d98c9f|2025-02-02 16:14:56.842481|Malasaña, Madrid|severe       |weather-related|2.0             |
# |afa2a568-345f-459e-be24-0b42937b1739|2025-01-09 09:20:45.358017|Malasaña, Madrid|high         |roadwork       |1.5             |
# |2102d7a1-5362-48bf-a2e2-71a5138aa9fb|2025-01-30 16:55:59.617105|Malasaña, Madrid|moderate     |road congestion|1.2             |
# |484751cf-fdcd-4fb0-94dc-04b662a537f0|2025-02-01 13:56:49.890963|Malasaña, Madrid|low          |roadwork       |1.0             |
# |86bed365-4bb8-435e-a286-1062b2de7fe3|2025-02-28 23:31:54.635206|Chueca, Madrid  |moderate     |accident       |1.2             |
# |d3e191dd-b544-4083-8cba-6c92d814f16c|2025-01-02 06:45:14.262034|Chueca, Madrid  |low          |road congestion|1.0             |
# |93753d90-cd6f-4f40-9453-74813694b4af|2025-01-28 02:27:04.411641|Chueca, Madrid  |severe       |road congestion|2.0             |
# |aa9a9234-e1a0-4b31-8538-33f780602d1f|2025-02-15 16:58:50.609821|Chueca, Madrid  |high         |weather-related|1.5             |
# |7a282bee-e168-436a-9a1b-f651f71b0a3d|2025-02-17 12:15:30.205178|Chueca, Madrid  |moderate     |accident       |1.2             |
# |e861c99a-7e3b-4471-b057-90fb499f4a37|2025-02-23 23:50:36.618781|Chueca, Madrid  |low          |closed road    |1.0             |
# |5e67ac40-9399-4148-972e-39fa31e30bf8|2025-03-06 08:16:59.903935|Chueca, Madrid  |moderate     |road congestion|1.2             |
# |6a413456-63ad-4249-9209-e0e5d26ec2f9|2025-01-29 22:23:36.277234|Chueca, Madrid  |high         |road congestion|1.5             |
# |9634a5d0-3d5a-46a5-a675-89699511f097|2025-01-17 11:28:55.208572|Chueca, Madrid  |moderate     |weather-related|1.2             |
# +------------------------------------+--------------------------+----------------+-------------+---------------+----------------+
# only showing top 20 rows
#
#
# Monitoring stream progress for 1 minute...
#
# >>> RIDE STREAM STATUS:
# {'message': 'Getting offsets from KafkaV2[Subscribe[ride-events-group4]]', 'isDataAvailable': False, 'isTriggerActive': True}
# Progress: []
#
# >>> TRAFFIC STREAM STATUS:
# {'message': 'Initializing sources', 'isDataAvailable': False, 'isTriggerActive': True}
# Progress: []
# >>> RIDE STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
#
# >>> TRAFFIC STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
# >>> RIDE STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
#
# >>> TRAFFIC STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
# >>> RIDE STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
#
# >>> TRAFFIC STREAM STATUS:
# {'message': 'Getting offsets from KafkaV2[Subscribe[traffic-alerts-group4]]', 'isDataAvailable': False, 'isTriggerActive': True}
# Progress: [{'id': '23318d78-b4ca-4402-a458-b0178043434b', 'runId': '27e0e57c-c0a3-4fbd-b964-95a269bc4928', 'name': None, 'timestamp': '2025-04-22T14:58:43.358Z', 'batchId': 8, 'numInputRows': 2000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 86.18460742911316, 'durationMs': {'addBatch': 20347, 'commitOffsets': 41, 'getBatch': 0, 'latestOffset': 2721, 'queryPlanning': 14, 'triggerExecution': 23206, 'walCommit': 69}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[traffic-alerts-group4]]', 'startOffset': {'traffic-alerts-group4': {'0': 6200}}, 'endOffset': {'traffic-alerts-group4': {'0': 8200}}, 'latestOffset': {'traffic-alerts-group4': {'0': 8200}}, 'numInputRows': 2000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 86.18460742911316, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'FileSink[wasbs://laurag@iesstsabbadbab.blob.core.windows.net/traffic_stream]', 'numOutputRows': -1}}]
# >>> RIDE STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
#
# >>> TRAFFIC STREAM STATUS:
# {'message': 'Getting offsets from KafkaV2[Subscribe[traffic-alerts-group4]]', 'isDataAvailable': False, 'isTriggerActive': True}
# Progress: [{'id': '23318d78-b4ca-4402-a458-b0178043434b', 'runId': '27e0e57c-c0a3-4fbd-b964-95a269bc4928', 'name': None, 'timestamp': '2025-04-22T14:58:43.358Z', 'batchId': 8, 'numInputRows': 2000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 86.18460742911316, 'durationMs': {'addBatch': 20347, 'commitOffsets': 41, 'getBatch': 0, 'latestOffset': 2721, 'queryPlanning': 14, 'triggerExecution': 23206, 'walCommit': 69}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[traffic-alerts-group4]]', 'startOffset': {'traffic-alerts-group4': {'0': 6200}}, 'endOffset': {'traffic-alerts-group4': {'0': 8200}}, 'latestOffset': {'traffic-alerts-group4': {'0': 8200}}, 'numInputRows': 2000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 86.18460742911316, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'FileSink[wasbs://laurag@iesstsabbadbab.blob.core.windows.net/traffic_stream]', 'numOutputRows': -1}}, {'id': '23318d78-b4ca-4402-a458-b0178043434b', 'runId': '27e0e57c-c0a3-4fbd-b964-95a269bc4928', 'name': None, 'timestamp': '2025-04-22T14:59:16.507Z', 'batchId': 9, 'numInputRows': 0, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 0.0, 'durationMs': {'latestOffset': 439, 'triggerExecution': 439}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[traffic-alerts-group4]]', 'startOffset': {'traffic-alerts-group4': {'0': 8200}}, 'endOffset': {'traffic-alerts-group4': {'0': 8200}}, 'latestOffset': {'traffic-alerts-group4': {'0': 8200}}, 'numInputRows': 0, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 0.0, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'FileSink[wasbs://laurag@iesstsabbadbab.blob.core.windows.net/traffic_stream]', 'numOutputRows': -1}}]
# >>> RIDE STREAM STATUS:
# {'message': 'Processing new data', 'isDataAvailable': True, 'isTriggerActive': True}
# Progress: []
#
# >>> TRAFFIC STREAM STATUS:
# {'message': 'Getting offsets from KafkaV2[Subscribe[traffic-alerts-group4]]', 'isDataAvailable': False, 'isTriggerActive': True}
# Progress: [{'id': '23318d78-b4ca-4402-a458-b0178043434b', 'runId': '27e0e57c-c0a3-4fbd-b964-95a269bc4928', 'name': None, 'timestamp': '2025-04-22T14:58:43.358Z', 'batchId': 8, 'numInputRows': 2000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 86.18460742911316, 'durationMs': {'addBatch': 20347, 'commitOffsets': 41, 'getBatch': 0, 'latestOffset': 2721, 'queryPlanning': 14, 'triggerExecution': 23206, 'walCommit': 69}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[traffic-alerts-group4]]', 'startOffset': {'traffic-alerts-group4': {'0': 6200}}, 'endOffset': {'traffic-alerts-group4': {'0': 8200}}, 'latestOffset': {'traffic-alerts-group4': {'0': 8200}}, 'numInputRows': 2000, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 86.18460742911316, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'FileSink[wasbs://laurag@iesstsabbadbab.blob.core.windows.net/traffic_stream]', 'numOutputRows': -1}}, {'id': '23318d78-b4ca-4402-a458-b0178043434b', 'runId': '27e0e57c-c0a3-4fbd-b964-95a269bc4928', 'name': None, 'timestamp': '2025-04-22T14:59:16.507Z', 'batchId': 9, 'numInputRows': 0, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 0.0, 'durationMs': {'latestOffset': 439, 'triggerExecution': 439}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[traffic-alerts-group4]]', 'startOffset': {'traffic-alerts-group4': {'0': 8200}}, 'endOffset': {'traffic-alerts-group4': {'0': 8200}}, 'latestOffset': {'traffic-alerts-group4': {'0': 8200}}, 'numInputRows': 0, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 0.0, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'FileSink[wasbs://laurag@iesstsabbadbab.blob.core.windows.net/traffic_stream]', 'numOutputRows': -1}}, {'id': '23318d78-b4ca-4402-a458-b0178043434b', 'runId': '27e0e57c-c0a3-4fbd-b964-95a269bc4928', 'name': None, 'timestamp': '2025-04-22T14:59:26.931Z', 'batchId': 9, 'numInputRows': 0, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 0.0, 'durationMs': {'latestOffset': 440, 'triggerExecution': 440}, 'stateOperators': [], 'sources': [{'description': 'KafkaV2[Subscribe[traffic-alerts-group4]]', 'startOffset': {'traffic-alerts-group4': {'0': 8200}}, 'endOffset': {'traffic-alerts-group4': {'0': 8200}}, 'latestOffset': {'traffic-alerts-group4': {'0': 8200}}, 'numInputRows': 0, 'inputRowsPerSecond': 0.0, 'processedRowsPerSecond': 0.0, 'metrics': {'avgOffsetsBehindLatest': '0.0', 'maxOffsetsBehindLatest': '0', 'minOffsetsBehindLatest': '0'}}], 'sink': {'description': 'FileSink[wasbs://laurag@iesstsabbadbab.blob.core.windows.net/traffic_stream]', 'numOutputRows': -1}}]
#
# Monitor finished: End of debigging cycle.
#
# Streams interrupted correctly

# %%
df_from_blob = spark.read.parquet(wasbs_base_path + "ride_stream")
df_from_blob.show(5)
# Out:
# +--------------------+--------------------+----------------+------------+--------------------+-------------------+--------------------+-----+
# |            event_id|             ride_id|      event_type|   uber_type|      start_location|       end_location|     timestamp_event|price|
# +--------------------+--------------------+----------------+------------+--------------------+-------------------+--------------------+-----+
# |6f1a1234-6785-450...|f08afdcf-ed3c-45b...|         Request|regular_uber| Plaza Mayor, Madrid|   Gran Via, Madrid|2025-03-14 16:20:...| NULL|
# |4b2d5dc8-3d98-441...|f08afdcf-ed3c-45b...|Driver available|regular_uber| Plaza Mayor, Madrid|   Gran Via, Madrid|2025-03-14 16:20:...| NULL|
# |8b779c1c-167f-4d6...|f08afdcf-ed3c-45b...|  Start car ride|regular_uber| Plaza Mayor, Madrid|   Gran Via, Madrid|2025-03-14 16:20:...| 3.94|
# |058fd86a-16e9-48d...|f08afdcf-ed3c-45b...|   Ride finished|regular_uber| Plaza Mayor, Madrid|   Gran Via, Madrid|2025-03-14 16:20:...| 3.94|
# |a96253e5-ff8c-4fa...|f26a42af-12ac-4ef...|         Request|regular_uber|Barrio de Salaman...|Plaza Mayor, Madrid|2025-03-14 16:20:...| NULL|
# +--------------------+--------------------+----------------+------------+--------------------+-------------------+--------------------+-----+
# only showing top 5 rows

# %%
df_from_blob = spark.read.parquet(wasbs_base_path + "traffic_stream")
df_from_blob.show(5)
# Out:
# +--------------------+--------------------+----------------+-------------+---------------+----------------+
# |            alert_id|           timestamp|         zone_id|traffic_level|     event_type|surge_multiplier|
# +--------------------+--------------------+----------------+-------------+---------------+----------------+
# |fb64b065-f0a7-4e8...|2025-02-20 00:39:...|Malasaña, Madrid|     moderate|       roadwork|             1.2|
# |56ec0c76-fe23-404...|2025-02-03 11:02:...|Malasaña, Madrid|     moderate|road congestion|             1.2|
# |86c9b201-8745-43e...|2025-01-21 06:20:...|Malasaña, Madrid|       severe|road congestion|             2.0|
# |c851ca6c-8779-4d0...|2025-03-05 01:02:...|Malasaña, Madrid|       severe|road congestion|             2.0|
# |da7e278f-1470-407...|2025-01-04 06:43:...|Malasaña, Madrid|     moderate|road congestion|             1.2|
# +--------------------+--------------------+----------------+-------------+---------------+----------------+
# only showing top 5 rows
